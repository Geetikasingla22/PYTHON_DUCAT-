# %% [markdown]
# # 1. lower ()

# %%
a="HII everyone,Geetika  here."
a= a.lower()
print(a)
# Out:
# hii everyone,geetika  here.

# %% [markdown]
# # 2. upper()

# %%
a="HII everyone,Geetika  here."
print(a.upper())
# Out:
# HII EVERYONE,GEETIKA  HERE.

# %% [markdown]
# # 3.title()

# %%
a="HII everyone,Geetika  here."
a=a.title()
print(a)
# Out:
# Hii Everyone,Geetika  Here.

# %% [markdown]
# # 4.capitalize()

# %%
a="HII everyone,Geetika  here."
a=a.capitalize()
print(a)
# Out:
# Hii everyone,geetika  here.

# %% [markdown]
# # 5.strip()

# %%
a="  Hii everyone,Geetika  here. " # remove starting and ending space
a=a.strip()
print(a)
# Out:
# Hii everyone,Geetika  here.

# %% [markdown]
# # 6.rstrip()/lstrip()

# %%
a="  Hii everyone,Geetika  here. " 
print(a.lstrip())
print(a.rstrip())
# Out:
# Hii everyone,Geetika  here.
#   Hii everyone,Geetika  here.

# %% [markdown]
# # 7.replace(old, new)

# %%
a="  Hii everyone,Geetika  here. " 
a.replace("here","there")
# Out:
# '  Hii everyone,Geetika  there. '

# %% [markdown]
# # 8.split()

# %%
a="  Hii .everyone. Geetika.  here. " #string ko list m break krta h 
a.split(".")
# Out:
# ['  Hii ', 'everyone', ' Geetika', '  here', ' ']

# %% [markdown]
# # 9.join()

# %%
 #List ko string me convert karta hai
l = ['apple ', 'banana', 'cherry']
print("-".join(l))
# Out:
# apple -banana-cherry

# %% [markdown]
# # 10.find()

# %%
a="  Hii everyone,Geetika  here. "  #First occurrence ka index deta hai
print(a.find("o"))
# Out:
# 11

# %% [markdown]
# # 11. index()

# %%
a="  Hii everyone,Geetika  here. " 
print(a.index("o"))
# Out:
# 11

# %% [markdown]
# # 12.count()

# %%
a="  Hiii everyone,Geetika  here. "
print(a.count("i"))
# Out:
# 4

# %% [markdown]
# # 13.startswith()

# %%
a=" hii everyone geetika"
print(a.startswith("g"))
b="geetika"
print(b.startswith("g"))
# Out:
# False
# True

# %% [markdown]
# # 14. endswith()

# %%
a=" hii everyone geetika"
print(a.endswith("a"))
# Out:
# True

# %% [markdown]
# # 15.isalpha()

# %%
a = "hii everyone geetika" # to check if there is only letters don't accept num,symbols and space 
print(a.isalpha())
a = "hiieveryonegeetika"
print(a.isalpha())
a = "hii2everyoneeetika"
print(a.isalpha())
a = " hiieveryonegeetika"
print(a.isalpha())

# %% [markdown]
# # 16.isdigit()

# %%
a = "123" # only accept digits
print(a.isdigit())
# Out:
# True

# %% [markdown]
# # 17.isalnum()

# %%
a = "123hii" # only accept digits with letter
print(a.isalnum())
# Out:
# True

# %% [markdown]
# # 18.isspace()

# %%
a = " 123 hii " # only accept space
print(a.isspace())
a = " " 
print(a.isspace())
# Out:
# False
# True

# %% [markdown]
# # 19.swapcase()

# %%
# Use: Upper → lower & lower → upper
a= "i AM THE STUDENT OF ducat"
print(a.swapcase())
# Out:
# I am the student of DUCAT

# %% [markdown]
# # 20.zfill(width)

# %%
# Use: Left me zeros add karta hai(hm isme total no. of digit specify krte h that we want 
a = "5"
print(a.zfill(6))
# Out:
# 000005

# %% [markdown]
# # 21.center(width)

# %%
s = "hi"
print(s.center(8, "="))
# Out:
# ===hi===

# %% [markdown]
# # 22.len()

# %%
a="hello guys"
print(len(a))
# Out:
# 10

# %% [markdown]
# # 23.casefold()

# %%
a="hELLo gUys"
print(a.casefold())
# Out:
# hello guys

# %% [markdown]
# # 24.format()

# %%
a="geetika"
print("Hello {}".format(a))
# Out:
# Hello geetika

# %% [markdown]
# # 25.format_map()

# %%
data = {"name": "Geetu"}
print("Hello {name}".format_map(data))
# Out:
# Hello Geetu

# %% [markdown]
# # 26.encode()

# %%
s = "hello" #String ko bytes me convert karta hai
print(s.encode())
# Out:
# b'hello'

# %% [markdown]
# # 27.expandtabs()

# %%
#Tabs (\t) ko spaces me convert karta hai
s = "hello\tworld"
print(s.expandtabs(4))
# Out:
# hello   world

# %% [markdown]
# # 28.partition()

# %%
s = "hello-world-priya-sriya" #divide it in three parts 
print(s.partition("-"))
# Out:
# ('hello', '-', 'world-priya-sriya')

# %% [markdown]
# # 29.rpartition()

# %%
s = "a-b-c" #Last occurrence se split karta hai 
print(s.rpartition("-"))
# Out:
# ('a-b', '-', 'c')

# %% [markdown]
# # 30. splitlines()

# %%
# Multi-line string ko list me convert karta hai
s = """hello world
how r uh
whats about uh"""
print(s.splitlines())
# Out:
# ['hello world', 'how r uh', 'whats about uh']

# %% [markdown]
# # 31.removeprefix()

# %%
# Prefix remove karta hai
s = "unhappy"
print(s.removeprefix("un"))
# Out:
# happy

# %% [markdown]
# # 32.removesuffix()

# %%
# suffix remove karta hai
s = "suddenly"
print(s.removesuffix("ly"))
# Out:
# sudden

# %% [markdown]
# # 33.isdecimal()

# %%
#Decimal numbers check karta hai
s = "123"
print(s.isdecimal()) # doubt
# Out:
# True

# %% [markdown]
# # 34. isnumeric()

# %%
#Numeric values (including special numbers)
s = "234/4"
print(s.isnumeric())# doubt
# Out:
# False

# %% [markdown]
# # 35.isidentifier()

# %%
#Check karta hai valid variable name hai ya nahi
s = "if"
print(s.isidentifier())# doubt
# Out:
# True

# %% [markdown]
# # 36.isprintable()

# %%
s = "hello"
print(s.isprintable())
# Out:
# True

# %% [markdown]
# # 37.istitle()

# %%
s = "Hello"
print(s.istitle())
# Out:
# True

# %% [markdown]
# # 38. islower()

# %%
s = "Hello"
print(s.islower())
# Out:
# False

# %% [markdown]
# # 39. isupper()

# %%
s = "HELLO"
print(s.isupper())
# Out:
# True

# %% [markdown]
# # 40. rfind() / rindex()

# %%
s = "HELLO" # last occurence k index ko show krega 
print(s.rfind("E"))
print(s.rindex("L"))
# Out:
# 1
# 3

# %% [markdown]
# # 41. ljust()

# %%
s = "HELLO" 
print(s.ljust(5,"*"))
# Out:
# HELLO

# %% [markdown]
# # 42. rjust()

# %%
s = "  HELLO" 
print(s.ljust(5,"*"))
# Out:
#   HELLO
